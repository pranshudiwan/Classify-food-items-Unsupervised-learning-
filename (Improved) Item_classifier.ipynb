# %% [markdown]
# # Text Classification of food items (Unsupervised Learning, with improved accuracy)

# %% [markdown]
# In this notebook, I will attempt to classify a food items database into their appropriate segments.

# %% [markdown]
# # Contents

# %% [markdown]
# 1. Introduction
# 2. Text Pre-processing
# 3. Text-to-features (Feature Engineering)
# 4. Text modelling
# 5. Text Classification
# 6. Testing and exporting
# 7. Conclusion

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# In the following problem, we have a database 'item_list.csv' having 2 columns, item_name and item_id. The tasks are:
#
# 1. To come up with appropriate segments for the food items
# 2. Train a model that predicts the segments

# %% [markdown]
# **This is what I did in my previous attempt:**

# %% [markdown]
# *"For the first part, I will use clustering algorithm as the problem is unsupervised. For the second part, I will extract labels from the clusters and use them as features for clustering.*
#
# *I will be using Word2Vec using gensim, as Word2Vec has the power to produce word embeddings. Other models like bag of words, tf-idf will not give us the co-relation between the words.*
#
# *As an alternative, I will also be using TextBlob with the NaiveBayesClassifier as it can give a better result than K-means using Scikit-Learn.*
#
# *I wanted to use GloVe and fastText as well, so that we could have had an overview all all models an chosen the best one."*

# %% [markdown]
# **For a second attempt, I decided to use GloVe (it attempts to obtain high-dimensional vector representations of words using global word-word co-occurrence) and SpaCy (a general purpose NLP tool which also happens to include pre-trained vectors for the most common English words using the GloVe Common Crawl.)**

# %% [markdown]
# So, in short, I'll be making meta-labels(topic_keywords) based on my overview of the data.
# Also, I'll be defining the labels(topic_labels) before I train the model.
#
# Then, I'll convert each keyword to a vector using GloVe.
# Following which, I'll convert our data into vectors as well.
#
# Finally, I'll compute a similarity matrix of each keyword to each topic, which gives us the output.

# %% [markdown]
# ## 1.1 Sneak-peak at data

# %%
#Importing stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import nltk

# %%
import spacy
import en_core_web_md

# %%
# Import database
dataset=pd.read_csv('item_list.csv', encoding='ISO-8859-1')

# %%
# Sneak-peak of data
dataset.head()
# Out:
#    Unnamed: 0           item_name     id
# 0           0      peri peri wrap   2444
# 1           1          gi-7161-19  24806
# 2           2  Milk Chocolate Tub  22729
# 3           3   Soft Drinks Large  12419
# 4           4     Cheese Omellete   3421

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28922 entries, 0 to 28921
# Data columns (total 3 columns):
# Unnamed: 0    28922 non-null int64
# item_name     28922 non-null object
# id            28922 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 677.9+ KB

# %% [markdown]
# I tried to solve the issue of not deleting the id's in the following way:
#     1. Making all required changes to data without deleting the id
#     2. Slicing and storing id column in a dataframe before modelling
#     3. Appending the id frame back to the original database
#
# The issue in this was:
# After making all changes to data, there are less entries in the data, and thus id and data could not be concatenated as the dimensions now differ.
#
# This issue will be solved(#1)

# %%
# Drop the unnecessary columns.
dataset.drop(labels = ["Unnamed: 0"], axis = 1, inplace = True)

# %%
#dataset.drop(labels = ["id"], axis = 1, inplace = True)

# %%
dataset.values
# Out:
# array([['peri peri wrap', 2444],
#        ['gi-7161-19', 24806],
#        ['Milk Chocolate Tub', 22729],
#        ...,
#        ['Thums Up 200 Ml', 5774],
#        ['Fruit Wine (Large)', 6561],
#        ['coca cola 300 ml', 20649]], dtype=object)

# %%
# Brief information about dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28922 entries, 0 to 28921
# Data columns (total 2 columns):
# item_name    28922 non-null object
# id           28922 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 452.0+ KB

# %%
#Check for null values
dataset.isnull().sum()
# Out:
# item_name    0
# id           0
# dtype: int64

# %%
dataset.describe()
# Out:
#                  id
# count  28922.000000
# mean   14463.499862
# std     8349.206819
# min        2.000000
# 25%     7233.250000
# 50%    14463.500000
# 75%    21693.750000
# max    28924.000000

# %%
dataset.head()
# Out:
#             item_name     id
# 0      peri peri wrap   2444
# 1          gi-7161-19  24806
# 2  Milk Chocolate Tub  22729
# 3   Soft Drinks Large  12419
# 4     Cheese Omellete   3421

# %% [markdown]
# Thus, in this section, we have had a good look at our data.

# %% [markdown]
# # 2. Text pre-processing

# %% [markdown]
# The dataset is raw and has many errors. We will implement three major changes in our dataset. They are:
#     1. Convert all data to lowercase
#     2. Get rid of the punctuation
#     3. Remove numbers from dataset
#     4. Remove specific elements having no significant use (delivery charges@30, gi--)

# %% [markdown]
# ## 2.1 Converting to lowercase

# %%
#Converting data to lower-case using Lambda function
a = dataset.apply(lambda x: x.astype(str).str.lower())

# %%
df1 = a['id']

# %% [markdown]
# In the above code, we have sliced and stored id column into a dataframe df1, which will be appended again to the main database. The problem here was after removing the punctuation, it deletes the id as well for some reason. Also, the number of rows are reduced, and should be in sync with id colun before slicing it.
#
# Will fix this issue(#1)

# %%
a.head()
# Out:
#             item_name     id
# 0      peri peri wrap   2444
# 1          gi-7161-19  24806
# 2  milk chocolate tub  22729
# 3   soft drinks large  12419
# 4     cheese omellete   3421

# %%
#new_a=a.drop('id',axis=1)

# %% [markdown]
# ## 2.2 Removing punctuation

# %%
# Getting rid of all punctuation
b=a.apply(lambda x: x.astype(str).str.replace('[^\w\s]',''))

# %%
b.shape
# Out:
# (28922, 2)

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28922 entries, 0 to 28921
# Data columns (total 2 columns):
# item_name    28922 non-null object
# id           28922 non-null object
# dtypes: object(2)
# memory usage: 452.0+ KB

# %% [markdown]
# ## 2.3 Removing digits

# %%
f=b['item_name'].str.replace('\d+', '')

# %%
f
# Out:
# 0                                        peri peri wrap
# 1                                                    gi
# 2                                    milk chocolate tub
# 3                                     soft drinks large
# 4                                       cheese omellete
# 5                                            cheesy dip
# 6                     blueberry cream cheese sw waffles
# 7                                            cafe mocha
# 8                                 exotic veg with sauce
# 9                                          basket chaat
# 10                                     red paprika half
# 11                                oreo obsessed pancake
# 12                                     raspberry medium
# 13                               chicken nuggets swiggy
# 14                                 chicken garlic salad
# 15                                    nuts over nutella
# 16                                  marshmallow brownie
# 17                                      delivery charge
# 18                    schezwan paneer pizza waffle half
# 19                                 espresso  cappuccino
# 20                                        matka chicken
# 21                                    pizza waffle full
# 22                                cottage cheese panino
# 23                                           xtra honey
# 24                                                   gi
# 25                        banana  salted caramel puffle
# 26                                nasty nutella pancake
# 27                                  whisky black  white
# 28                                             bbq wrap
# 29                                       veg fried rice
#                               ...
# 28892                                      twix pancake
# 28893                                  mini pancake muo
# 28894                               chicken shami kebab
# 28895                                 fresh veggie full
# 28896                             parle g caramel shake
# 28897                                 crab pepper roast
# 28898                              butter tandoori roti
# 28899                                    bottled water
# 28900                          aloo gobhi matar sukha n
# 28901                                 chilli paneer dry
# 28902                            go olives pizza medium
# 28903                         blueberry cheese cake jar
# 28904                                penne masala mafia
# 28905                       apple cinnamon pastry shake
# 28906                            chocoffe mini pancakes
# 28907     kolkata meetha paan ice cream with gulkand sc
# 28908                           classic vanilla cupcake
# 28909                                          espresso
# 28910                                  beet carrot juic
# 28911                      swiggy white chocolate shake
# 28912    off new link road oshiwara andheri west mumbai
# 28913                            honey  butter waffwich
# 28914                          crispy fried basa filled
# 28915                            paneer chilli sandwich
# 28916                                           granola
# 28917                               nasty nutella crepe
# 28918                marshmallow dark chocolate pancake
# 28919                                      thums up  ml
# 28920                                  fruit wine large
# 28921                                     coca cola  ml
# Name: item_name, Length: 28922, dtype: object

# %%
# Converting a pandas dataframe to a numpy array
c=f.values

# %%
c
# Out:
# array(['peri peri wrap', 'gi', 'milk chocolate tub', ..., 'thums up  ml',
#        'fruit wine large', 'coca cola  ml'], dtype=object)

# %% [markdown]
# ## 2.4 Removing specific words having no significance (delivery charge@30, gi--3557)

# %% [markdown]
# Here, since we do not know the index of the words in the database, we will use the argwhere() function.
#
# The issue here is this:
#     1. I have defined an array in every new line.
#     2. The names of defined arrays are confusing.
#
# Both the issues will be fixed(**#2**)

# %%
#Find and delete index having word as delivery charge@
index = np.argwhere((c=='delivery charge@'))
h=np.delete(c, index)

# %%
h
# Out:
# array(['peri peri wrap', 'gi', 'milk chocolate tub', ..., 'thums up  ml',
#        'fruit wine large', 'coca cola  ml'], dtype=object)

# %%
#Find and delete index having word as gi
index = np.argwhere(h=='gi')
i=np.delete(h, index)

# %%
i
# Out:
# array(['peri peri wrap', 'milk chocolate tub', 'soft drinks large', ...,
#        'thums up  ml', 'fruit wine large', 'coca cola  ml'], dtype=object)

# %%
d=i

# %%
d
# Out:
# array(['peri peri wrap', 'milk chocolate tub', 'soft drinks large', ...,
#        'thums up  ml', 'fruit wine large', 'coca cola  ml'], dtype=object)

# %% [markdown]
# Thus, we have successfully cleaned our text data.

# %% [markdown]
# # 3. Feature Engineering

# %% [markdown]
# Converting text data to vectors. I have taken the transpose of the clean data array and converted it to a list as the input parameter in the model requires a list

# %%
# Convert to matrix
x = np.matrix(d)

# %%
# Take transpose of matrix
e=x.T

# %%
# Convert back to array
A = np.squeeze(np.asarray(e))

# %%
# Convert array to list
keywords=np.array(A).tolist()

# %%
keywords
# Out:
# ['peri peri wrap',
#  'milk chocolate tub',
#  'soft drinks large',
#  'cheese omellete',
#  'cheesy dip',
#  'blueberry cream cheese sw waffles',
#  'cafe mocha',
#  'exotic veg with sauce',
#  'basket chaat',
#  'red paprika half',
#  'oreo obsessed pancake',
#  'raspberry medium',
#  'chicken nuggets swiggy',
#  'chicken garlic salad',
#  'nuts over nutella',
#  'marshmallow brownie',
#  'delivery charge',
#  'schezwan paneer pizza waffle half',
#  'espresso  cappuccino',
#  'matka chicken',
#  'pizza waffle full',
#  'cottage cheese panino',
#  'xtra honey',
#  'banana  salted caramel puffle',
#  'nasty nutella pancake',
#  'whisky black  white',
#  'bbq wrap',
#  'veg fried rice',
#  'feta greek',
#  'penne creamy pesto',
#  'choco chips',
#  'white chocolate puffle',
#  'delivery charge',
#  'dark chocolate waffwich',
#  'dark chocolate sauce',
#  'chocolate chips white',
#  'crispy chilli potato',
#  'spicy corn kernel fr rice half',
#  'butterscotch crunch',
#  'nioxin derma renew',
#  'dark chocolate mousse',
#  'nutella puffle',
#  'khushgrill chicken steak with cheese',
#  'wash and blow dry creative director',
#  'grilled paneer salad',
#  'mushroom pizza',
#  'death by chocolate cupcake',
#  'veg salad',
#  'apple cinnamon pastry shake',
#  'strawberry creamcheese',
#  'choco panipuri',
#  'blue sapphire margarita',
#  'cheese chilly toast',
#  'white chocolate mini pancake',
#  'amritsari chana masala',
#  'marshmallow nutella pancake',
#  'tomato basil soup',
#  'anda paratha',
#  'citrus cheese cake slice',
#  'veg cheese pizza',
#  'green apple iced tea',
#  'add icecream',
#  'kolhapuri chicken sw',
#  'almond thins',
#  'peach passion fruit tea',
#  'mexican mania pizza large',
#  'peri peri mayo',
#  'pahadganj palak paneer',
#  'whisky sour ',
#  'gordons ',
#  'fresh strawberry',
#  'oreo mad shake',
#  'peanut butter  jam pancake',
#  'belgian chocolatemilk',
#  'fresh strawberry small',
#  'nutella fries with bacon',
#  'hot chocolate candy',
#  'hara bhara kebab',
#  'classic nachos',
#  'red velvet',
#  'chicken jungli sandwich',
#  'lemon mojito',
#  'red bul energy drink',
#  'forest green amp sunshine pizza regular',
#  'twix pancake',
#  '',
#  'swiss choco almond mini pancakes',
#  'delivery charge',
#  'paneer tikka pizza dine in',
#  'kit kat',
#  'stuff mushrooms',
#  'chicken fry indian',
#  'caramel sea salt shake',
#  'peach passion',
#  'dal khichdi full',
#  'pepperoni mushroom cocas',
#  'cesar salad veg dine in',
#  'fresh fruits w cream belgian',
#  'patata bravas',
#  'neck threading',
#  'americano',
#  'choco delight cake',
#  'jeera rice',
#  'delivery charge',
#  'fruit and nut polish',
#  'punjabi onion kulcha combo',
#  'andheri west',
#  'boiled egg  pcs',
#  'delivery charge',
#  'chicken noodles',
#  'pb  chocolate',
#  'prawns goan curry',
#  ' classic steak   mocktails',
#  'moroccanoil intense hydrating mask  ml',
#  'choclate shake',
#  'thc ballvic hair pack  ml',
#  'non vegetarian platter',
#  'kulfi falooda',
#  'paneer paradise pizza small  inches',
#  'mexican loaded nachos',
#  'breakfast nachos',
#  'red velvet cake jar',
#  'mutton do pyaza',
#  'frozen margarita',
#  'brownie chunks add on',
#  'nutties waffle',
#  'xl breakfast sides bacon',
#  'green tea',
#  'greek salad',
#  'chicken caesar salad',
#  'smokin gold pizza small  inches',
#  'crispies',
#  'jamun bliss juic',
#  'americano',
#  'creamy makhni pasta veg',
#  'hazelnut brownie shake',
#  'rickshaw gali shawarma chicken',
#  'watermelon',
#  'follow through   sessions  boosters thc set ',
#  'clasic masala small',
#  'strawberry cheesecake belgian',
#  'cheese margherita pizza  inc',
#  'paneer makhmali kebab',
#  'fresh espresso small',
#  'maple syrup',
#  'walnut brownie lg',
#  'irish black',
#  'blue cool',
#  'cheese naan',
#  'amritsari bharwan kulchamasala',
#  'veg lemon and coriander soup',
#  'italiano chicken wings',
#  'masala dosa ',
#  'mutton rogan josh',
#  'white chocolate waffwich',
#  'dark white pancake',
#  'palak paneer',
#  'banana rumba qtr bb',
#  'mar',
#  'wan',
#  'quatro stagoni veg pizza large large',
#  'sitaphal small',
#  'grilled chicken gm',
#  'tea',
#  'schezwan vada pav',
#  'gooey jalapeno poppers',
#  'roasted lemon  olive pepper chicken',
#  'lemon mojito',
#  'strawberry cake ',
#  'protein pro salad',
#  'butter tandoori roti',
#  'extra cheese',
#  'veg grill',
#  'bridal makeup',
#  'brownie belgian white mini pancakes',
#  'apple cream',
#  'make your own full mad veg pizza',
#  'thai green curry',
#  'mint mojito',
#  'paneer makhanwala steam rice  roti dal aachar chaas  sweet',
#  '',
#  'poppers  wedges',
#  'milk chocolate sauce',
#  'honey  butter mini pancake',
#  'pure milk chocolate  f',
#  'delivery',
#  'milk chocolate sauce',
#  'mr white',
#  'mumbai local quesadilla',
#  'kiwi smoothie',
#  'oreo  shake',
#  'grapes juice',
#  'uncafe pizza',
#  'flat white',
#  'ws',
#  'penne arabiatta',
#  'aqua aerobicsanand pardesi',
#  'honey  butter waffwich',
#  'american dream pancake',
#  'nutella mini pancake',
#  'orange',
#  'palak paneer',
#  'belgian dark belgian',
#  'kitkat mini pancakes',
#  'noodle doodle wrap',
#  'choco chip panna cotta',
#  'delivery charge',
#  'belgian chocolatemilk',
#  'pizza waffle half',
#  'chili cheese toast',
#  'gst test ',
#  '',
#  'tandoori aloo',
#  'creal crunch single',
#  'frappe served cold',
#  'delivery',
#  'whisky chivas regal y df',
#  'marshmallow nutella belgian',
#  'kit kat belgian',
#  'nutella overload waffle',
#  'pindi choley',
#  'parmesan fries',
#  'tiramisu ',
#  'oreo obsessed crepe',
#  'egg triple schezwan fried rice',
#  'fruit juice detox',
#  'strawberry cooler',
#  'banana maple choco belgian',
#  ' layer cake pastry',
#  'usmani chai',
#  'bbq chiken burger',
#  'milk chocolate sauce',
#  'hummus  pita',
#  'raspberry ice tea',
#  'polo pizza large medium',
#  '',
#  'milkmaid madness pancake',
#  'mango waffle',
#  'creamy hummus  inactive',
#  'delivery charge',
#  'pani puri',
#  'brownie belgian white chocolate ww',
#  'french fries',
#  'chocolate overloaddark',
#  'chocolate volcano pancake',
#  'white chocolate mini pancake',
#  'moroccanoil repair spring kit pack of ',
#  '',
#  'dragon blueberry juice highest antioxidant',
#  'the dark white waffwich',
#  'table',
#  'papad',
#  'red velvet  kg',
#  'bruschetta',
#  'brownie belgian dark white puffle',
#  'amritsari kulcha aloo',
#  'hh veg classy fam',
#  'nachos and salsa',
#  'chicken pepper masala',
#  'coke  can   ml',
#  'cheese omlet',
#  'twc special waffles double',
#  'zomato delivery',
#  'veg chilli garlic noodles',
#  'smile wrap',
#  'maple  butter puffle',
#  'delivery charge',
#  'sprite',
#  'bacon and cheese grilled swiggy',
#  'soda duck   ml',
#  'banana  salted caramel pancake',
#  'paneer tikka pizza  inch',
#  'table',
#  'sys pro balance shampoo ml multilang',
#  'mango ice cream tub',
#  'nutella shake',
#  'dark chocolate puffle',
#  'penne masala mafia',
#  'by',
#  'arabic grill fish',
#  'chocolate overloadmilk',
#  'white chocolate sauce',
#  'lemon iced tea',
#  'chicken junglee sandwich',
#  'kiwi kiss half bb',
#  'red velvet crumbled single',
#  'fried rice veg full',
#  'oreo  kg',
#  'chocolate brownie',
#  'aloo jeera masala',
#  'red velvet waffle',
#  'mushroom half',
#  'bhuna chicken',
#  'veg pesto pizza',
#  'xtra white choc',
#  'wnie',
#  'oreo crumble',
#  'fruit wine glass',
#  'lemon mojito',
#  'chili cheese open toast',
#  'measurable  collagen smoothie face mask',
#  'english tea',
#  'white chocolate pancake',
#  'grill cheese burnt garlic',
#  'classic lemon iced tea',
#  'peach ice tea',
#  'dudhi carrot',
#  'delivery charge',
#  'nutella macaron',
#  'paneer kulcha',
#  'coffee waffwich',
#  'exotic lasagne',
#  'mango mojito',
#  'dark chocolate waffwich',
#  'paneer family biryani',
#  'cheese  mushroom risottos',
#  'coffee cup',
#  'pesto sundried tomato pizza',
#  'tomato cream soup ',
#  'paneer chilli',
#  'corn on the cub pizza  inches',
#  'french fries',
#  'nutella cookie',
#  'methi paneer tikka',
#  'opera cake',
#  'cheese paratha',
#  'anjeer juice',
#  'bbq spicy chicken supreme sizzlers',
#  'banana',
#  'speckled berry pancake',
#  'strawberry  banana shake',
#  'extra cheese',
#  'french fry nacho',
#  'sys pro balance energy scalp serum addon',
#  'vanilla cinnamon doughnut',
#  'bag large',
#  'swiss chocolate pastry',
#  'chocolate frappe',
#  'nutella affair',
#  'peanut butter  jam puffle',
#  'belgian white belgian',
#  'cheesy arrabita pasta',
#  'cookie dough double',
#  'ese',
#  'peach iced tea',
#  'triple chocolate',
#  'brownie',
#  'plain cone single',
#  'toffee mini pancake',
#  'cupcakes chocolate',
#  'hazelnut brownie',
#  'moroccanoil hydrating spring kit pack of ',
#  'egg chopper rice',
#  'prawn pepper masala',
#  'chocolate volcano pancake',
#  'mayo grilled chicken ',
#  'water',
#  'amritsari chat pate aloo',
#  'jeera mojito',
#  'delivery charge',
#  'exotic salad',
#  'pink sauce pasta chicken',
#  'mushroom fried rice',
#  'cheese burnt garlic',
#  'rosted piastachio tub',
#  'blue berry mojito',
#  'fresh blueberry shk',
#  'honey and pista ',
#  'extra cheese',
#  'choco muffin',
#  'hummus  pita',
#  'prawns chili',
#  'double chicken pork juggernaut ftb',
#  'dark hot chocolate',
#  'restaurant cleaning fees',
#  'banana mango smoothies',
#  'cream chicken puff',
#  'marshmallow nutella ww',
#  'salted caramel popcorn small',
#  'apple cinnamon rush pancake',
#  'table',
#  'veg ramen',
#  'brownie magic',
#  'roasted tomato bell pepper and fresh mushroom pizza',
#  'partial qod  medium',
#  'sweet lime juice',
#  'dal fry',
#  'molmolletta clip  french',
#  'xtra caramel',
#  'waffle with ice cream',
#  'bolognese',
#  'wet brush  combo tattoo orange',
#  'belgian milk chocolate waffwich',
#  'paneer teriyaki',
#  'chicken seekh',
#  'chicken ghee roast',
#  'oreo small',
#  'mutton nawabi steam haif',
#  'stirfried pok choy',
#  'blue berry mojito',
#  'waffle muo',
#  'sizzling brownie  with vanilla ice cream',
#  'phulka tacos with lal maas',
#  ' spice full',
#  'delivery',
#  'chilly potato',
#  'topping anar',
#  'ikoo  cotton candy  white base',
#  'cheesy baked french fries',
#  'assam tea',
#  'amritsari chole',
#  'iced latte black',
#  'popper wrap',
#  'crispies',
#  'methi paratha',
#  'pahadi chicken shawarma',
#  'pesto panner swiggy',
#  'tomato soup',
#  'periperi panner wrap',
#  'choclate shk',
#  'pasta arabiata',
#  'delivery charges  ',
#  'capsicum half',
#  'ferrero crunch medium',
#  'extra strawberry',
#  'pineapple fried rice ',
#  '',
#  'dark chocolate belgian',
#  'fresh mango',
#  'chocolate hazelnut shake dine in',
#  'pb  chocolate',
#  'choco chips  gems belgian',
#  'americano',
#  'mr white',
#  'veg salad',
#  'coffee arabica',
#  'red velvet waffle',
#  'green apple iced tea',
#  'whipped cream',
#  'pesto sauce chicken',
#  'masala fries',
#  'salted caramel  hazelnut cakekg',
#  'chocolate float',
#  'red velvet waffle',
#  'rabdi',
#  'peanut butter waffle single',
#  'pink pearls salad  inactive',
#  'skillet mushroom fries',
#  'cookie dough tub',
#  'topping cone double',
#  'belgian dark belgian',
#  'missal fondue large',
#  'mint mojito',
#  'belgian chocolate medium',
#  'mango mojito',
#  '',
#  'chicken combo for ',
#  'double juggernaut pork contains bacon',
#  'missal fondue small',
#  'penne arabiatta',
#  'twix waffle',
#  'death  y chocolate waffle  pcs',
#  'nutella single',
#  'belgian chocolatedark',
#  'malt cooler',
#  'apple cinnamon shake',
#  'green tea',
#  'cookiewich',
#  'black forest pastry',
#  'stuffed omlet',
#  'paneer bbq rice',
#  'swiss chocolate pastry',
#  'hummus with zaatar naan',
#  'pink velvet macaron',
#  'naked nutella',
#  'non veg buffetweekends',
#  'caramel castle pancake',
#  'neopolitan cupcake',
#  'chocolate overloaddark',
#  'twix pancake',
#  'new tomato basil cheese pizza',
#  'kullad chai',
#  'chicken tandoori masala n',
#  'chocolate overloaddark',
#  'mocha macaron',
#  'papad',
#  'garlic bread spicy exotica',
#  'ola brm mulberry',
#  'cheese croissant',
#  'ganache cupcake',
#  'aglio olio veg swiggy',
#  'basmati steamed rice',
#  'raspberry small',
#  'gooey jalapeno poppers',
#  'crispy bhindi fry',
#  'tsg mini tennis   month',
#  'classic masala toast',
#  'coconut milk chocolate  f',
#  'smoothie mango',
#  'brownie belgian dark chocolate ww',
#  'veg manchow soup',
#  'uncafe pizza',
#  'free classic supreme ',
#  'mini marshmellows single',
#  'every day ricechicken',
#  'mango delight',
#  'mango mojito',
#  'supergrain breadgrams',
#  'biguine bio normalizing facial',
#  'dragon juice',
#  'buttock waxing',
#  'maa ke hath ki paneer dal khichdi',
#  'belgian dark belgian',
#  'berry blast milkshake',
#  'iced mocha blended regular',
#  'mos palak amla letus',
#  'litchi shake',
#  'nasty nutella pancake',
#  'cheese masala pav',
#  'nasty nutella crepe',
#  'butterscotch belgian',
#  'nutmeg powder',
#  'sally hansen  pedicure moisturizing foot cream   gm',
#  'twisties fried chicken combo dine in',
#  'crispy chilli cheese veg haif',
#  'spice grilled chicken burger',
#  'cookies and creame p',
#  'water chestnuts  tofu',
#  'pizza  grill',
#  'grp confusion',
#  'butter scotch caramel milkshake',
#  'snicker pancake',
#  'veg combination rice',
#  'blueberries',
#  'wella  wp eimi sculpt force   ml',
#  'mini pancake muo',
#  'whisky black  white',
#  'spanish cottage cheese prawn wrap',
#  'khurmi  naan',
#  'blueberry cheesecake belgian',
#  'blue berry mojito',
#  'strawberry oreo shake',
#  'white chocolate sauce',
#  'red velvet waffle',
#  'nasty nutella crepe',
#  'ladies drink ',
#  'chipotle panner pizza dine in',
#  'dark chocolate pancake',
#  'pita  toast  pav',
#  'kitkat shake',
#  'walnut brownie reg',
#  'mango ice cream medium',
#  'classic hot chocolate',
#  'snicker crepe',
#  'fresh strawberry',
#  'nutella double',
#  'packaging charges',
#  'oreo obsessed pancake',
#  'jalapenos half',
#  'sweet fresh lime water',
#  'gobi  indian',
#  'uncafe pizza',
#  'triple chocolate   inactive',
#  'alfredo pasta',
#  'mini pancake muo',
#  'wine grover sauvblanc ac',
#  'extra pita',
#  'mango shake',
#  'murgh pudina kathi',
#  'aloo paratha',
#  'stuff mushrooms',
#  'bbq fries',
#  'kit kat puffle',
#  'naan  plain',
#  'chicken sukha',
#  'nutties waffle',
#  'kit kat',
#  'litchi cooler',
#  'white chocolate sauce',
#  'strawberrytella pancake',
#  'food for staff sick',
#  'veg kadhai turnover',
#  'nutella mini pancake',
#  '',
#  'indie joe',
#  'silken tofu in hunan sauce',
#  'triple chocolate brownie ice cream',
#  'oreo obsessed pancake',
#  'ncshakes',
#  'hot chocolate',
#  'coupe de glace',
#  'andewali dal ',
#  'sprinking kiwi cooler',
#  'farm fresh pizza ',
#  'banana',
#  'very berry',
#  'cold coffee with ice cr eam',
#  'granola cookie',
#  'chicken classic steak with  cheese',
#  'belgian style',
#  ' mosambi',
#  'banana oats muffins',
#  'paneer tikka pizza',
#  'oreo obsessed pancake',
#  'oriental paneer',
#  'brown rice makhani',
#  'cheesy jalapeno poppers',
#  'pizza fondue small',
#  'brownie',
#  'belgian chocolate small',
#  'an oat date',
#  'kullad chai',
#  'molsmall clawbrown  ivory',
#  'delivery charge',
#  'plain pita bread  inactive',
#  'banana  salted caramel mini pancake',
#  'banana maple choco mini pancakes',
#  'chocolate smoothies',
#  'classic margarita dine in',
#  'chocolate volcano pancake',
#  'red velvet pastry',
#  'dark  white fantasy',
#  'red velvet cake jar',
#  'spicy guvava small',
#  'belgium chocolate milkshake',
#  'cottage cheese pepper sauce',
#  'chipotle wedges',
#  'garlic toast  gms',
#  'white chocolate waffwich',
#  'mango mojito',
#  'bottled water',
#  'fresh mint and choco chip small',
#  'peri peri fries',
#  'family biryani  nattukozhi',
#  'berrylicious shake',
#  'nasty nutella crepe',
#  'add fruit garden cake',
#  '',
#  'cheese burst spicy tst',
#  'grilled chicken burger',
#  'chicken tandoori sandwich',
#  'veg suan la tang',
#  'cold coffee',
#  'cheese garlic bread',
#  'delivery box',
#  'strawberry smoothie',
#  'burrito bowl',
#  'berry berry ',
#  'chocolate browine with nutella spread',
#  'nutties waffle',
#  'red bull',
#  'smooth ',
#  'veg chettinad',
#  'paneer tikka malai',
#  'prawns tikka ppp',
#  'white chocolate mini pancake',
#  'blueberry small',
#  'marghi na fracha',
#  'chilli sauce',
#  'mcb shake',
#  'honey  butter belgian',
#  'fresh fruits w cream puffle',
#  'egg chettinad',
#  'walnut apricoat',
#  'paani puri',
#  'chilli cheese wedges',
#  'classic cold chocolate doughnut',
#  'delivery charge',
#  'swiss choco almond pancake',
#  'apple cinnamon rush belgian',
#  'belgian milk chocolate puffle',
#  'caramel parle g mlkshake',
#  'egg bhuna rool',
#  'maharaja thali non veg',
#  'mutton tawa slider',
#  'cleanser juice',
#  'american dream pancake',
#  'desi deshi pizza',
#  'banana',
#  'chocolate burger ',
#  'indian grill chicken  full',
#  'cheese bbq fries',
#  'cookies  cream puffle',
#  'gooey jalapeno poppers',
#  'swiggy lemon mojito',
#  'belgian chocolate sundae',
#  'brownie belgian dark mini pancakes',
#  'dragon paneer',
#  'carrot halwa',
#  'chocolate volcano pancake',
#  'paneer tawa masala',
#  'fresh fruits w cream belgian',
#  'cheese cake crumbled single',
#  '',
#  'cookies  cream belgian',
#  'brownie belgian white chocolate ww',
#  'hariyali paneer',
#  'mexican loaded nachos',
#  'mini snack box',
#  'corn',
#  'chak de phatte',
#  'cheese corn tomato ',
#  'paneer bhurji',
#  'chicken kashmiri pulav',
#  'brownie belgian milk chocolate ww',
#  'cheese garlic bread',
#  'hibatchi noodle',
#  'delivery charge',
#  'schezwan corn sandwich',
#  'lacha paratha',
#  'nutella waffwich',
#  'cheese  bread   gm',
#  'stuff mushrooms',
#  'kit kat puffle',
#  'dark chocolate pancake',
#  'raspberry red ww',
#  'hot fudge sundae',
#  'chocolate brownie',
#  'belgian pure dark chocolate   gms',
#  'tandoori egg sandwich',
#  'peri peri fries',
#  'caramel sauce add on',
#  'zatar croissant',
#  'babycorn ',
#  'honey  butter mini pancake',
#  'paneer tikka panini',
#  'prawns  basa aglio e olio penne pasta',
#  'irani prawn',
#  'cottage cheese mushroom  quesadilla',
#  'chicken pink sacue penne pasta',
#  'dark hot choclate popcorn',
#  'pani puri sorbet',
#  'stir fried ch green',
#  'cappuccino vanill',
#  'murgh makhani',
#  'barcelona pizza medium',
#  'polo pizza large large',
#  'veg roll',
#  'veg mini grilled sandwich',
#  'cafe latte',
#  'siddharth',
#  'classic bruschetta',
#  'gooey jalapeno poppers',
#  'cappucino',
#  'oc',
#  'english  muffins',
#  'twix waffle',
#  'smooth blue mulb avac',
#  'three eggs omelet scrambled ham  cheese',
#  'dilevery charge',
#  'bubble gum candy floss tub',
#  'buffet  dinner   child',
#  'marshmallow w milk chocolate belgian',
#  'marshmallow w milk chocolate ww',
#  'triple schezwan rice veg',
#  'steak fataka wd cheese',
#  'loaded jalapeão cheese fondue small',
#  'ice cream',
#  'dal tadka',
#  'maple butter',
#  'pizza waffle half',
#  'chicken keema empadanas',
#  'cheese sauce',
#  'classic nachos',
#  'garlic bread',
#  'snickup',
#  'espresso',
#  'marshmallow white chocolate belgian',
#  'mexican spice',
#  'waffle muo',
#  'mexican mania veg pizza large medium',
#  'opi  nlm  my chihuahua bites   ml',
#  'sicilian pizza',
#  'no pnr add tofu',
#  'nutties waffle',
#  'peri peri mushroom half',
#  'chilli paneer',
#  'belgian milk ww',
#  'rasila paan',
#  'brown',
#  'couverture dark chocolate',
#  'veg combination schezwan',
#  'mushroom  cheese omlette',
#  'mint mojito',
#  'underarms waxing',
#  'dark chocolate puffle',
#  'nuts over nutella',
#  'delivery charge ',
#  'extra schezwan',
#  'schezwan paneer pizza waffle full',
#  'kadamba poritchadu',
#  'gooey jalapeno poppers',
#  'mushroom pizza  inactive',
#  'snicker pastry shake',
#  'strawberry cheesecake waffwich',
#  'nutella',
#  'add for nonveg',
#  'nutella shake',
#  'swiggy delivery',
#  'almond thins',
#  'marshmallow w dark chocolate belgian',
#  'peri peri fries',
#  'mango tango reg',
#  'oreo obsessed crepe',
#  'chicken schezwan lollipop',
#  'polenta steak',
#  '',
#  'chicken lollypop',
#  'delivery charges  ',
#  'dahi puri',
#  'vanilla cola',
#  'opi  nli  black cherry chutney   ml',
#  'ld',
#  'angels delight body butter ml bomb',
#  'sp mix',
#  'blueberry mini pancake',
#  'nasty nutella pancake',
#  'pure gold potato',
#  'choco lic',
#  'belgian chocolatemilk',
#  'corn mushroom  cheese wrap',
#  'smokey bbq cottage cheese',
#  'belgian milk chocolate belgian',
#  'swiss chocolate pastry',
#  'gg star pizza ',
#  'vanilla ice cream',
#  'table',
#  'gooey jalapeno poppers',
#  'hot chocolate',
#  'sys prof balance mask xml multilang',
#  'mango mojito',
#  'ganache  well cake shake',
#  'green apple cooler',
#  'indian tadka',
#  'signature mama rosso',
#  'cream cheese',
#  'fish clear soup',
#  'red thai curry rice with chicken',
#  'pudina tandoori momos nonveg',
#  'mr white',
#  'bbq wrap',
#  'valentine singlegg',
#  'chappathi',
#  'granola smoothie',
#  'rm banana',
#  'chili cheese toast',
#  'chocoorange silk',
#  'cold coffee',
#  'rm lemon',
#  'mama mia pizza  inactive',
#  'cappuccino coffee small',
#  'glov  makeup remover all skin type  on the go ivory',
#  'apple cinnamon',
#  'chicken delight burrito meals',
#  'mutton korma',
#  'cheese masti',
#  'mango chilli margarita',
#  'green effect new  ml',
#  'vanila shk',
#  'mint mojito',
#  'lamb cheese  corn stuffed burger',
#  'oreo obsessed pancake',
#  'black forest pastry',
#  'power meal combo',
#  'table',
#  'nasty nutella pancake',
#  'fresh strawberry',
#  'banana  salted caramel pancake',
#  'classic challenge steaks with cheese',
#  'mexican loaded nachos',
#  'dark choco chip tub',
#  'delivery',
#  'waffle muo',
#  'chocolate overloaddark',
#  'chilly chicken',
#  'lagan ka murgh',
#  'ganache cupcake',
#  'extra sw corn',
#  'the dark white waffwich',
#  'babyliss  dryer e',
#  'white cho mocha ',
#  'chilled carrot ginger',
#  'cheese mushroom',
#  'pineapple  kg',
#  'pishus exotic grill',
#  'prawn masala',
#  'chiken kalimiri kabab',
#  'french fries',
#  'spinach power meal',
#  'couverture dark chocolate',
#  'salted caramel cold coffee',
#  'twc special waffle single',
#  'corn on the cub pizza  inches',
#  'escential rose bead wax  grm',
#  'aloo tikki burger',
#  'magical bluebery juice',
#  'orange',
#  'absolute hydramarine concentratevtmlx',
#  'strawberry shake',
#  'caramel yogurt cheese cake low fat',
#  'add fruit',
#  'kit kat belgian',
#  'lacha paratha ',
#  'maple and butter mini pancake',
#  'chicken tikka masala pie',
#  'twix pancake',
#  'strawberrykiwi',
#  'banana',
#  'butterscotch waffwich',
#  'patana paneer ke tikke',
#  'cheese crust',
#  'international beer ml',
#  'strawberry cheesecake waffwich',
#  'chicken clear soup with glass noodles',
#  'cheese garlic bread',
#  'apple cinnamon rush pancake',
#  'veg fried rice',
#  'mini pancake muo',
#  'veg croquettes  inactive',
#  'delivery charge',
#  'bbq veg pasta',
#  'srilankan curry',
#  'paneer bhurji grill',
#  'mexican loaded nachos',
#  'coke float',
#  'chili cheese toast',
#  'sweet corn ',
#  'chicken singapore rice',
#  'cheese amp tomato pizza',
#  'veg pastaaaaa',
#  'chocolate overloaddark',
#  'swiggy hummus pita',
#  'blue berry mojito',
#  'paneer chilli',
#  'mocha frappe lg',
#  'mocha fudge delight pastry gluten free',
#  'bolognese',
#  'caramal sauce double',
#  'paneer  indian',
#  'anjir shake',
#  'cottage cheese pepper sauce',
#  'plain cone single',
#  'strawberry petals',
#  'cinful sugar half ob',
#  'apple shk',
#  'curry leaf and chilli mayo',
#  'marshmallow w dark chocolate belgian',
#  'veg malai kofta',
#  'rivaayat nonvegetarian',
#  'chocolate shots',
#  'uncafe pizza',
#  'baigan ka bharta',
#  'gooey jalapeno poppers',
#  'classic masala',
#  'cracker pan tossed',
#  'white chocolate frappe',
#  'fresh espresso small',
#  'three eggs omelet scrambled mushroom  cheese',
#  'extra vanilla',
#  'makai aur mangodi ki subzi',
#  'mineral water',
#  'veg spagetti pasta  pink',
#  'brownie nutella mini pancakes',
#  'non veg club sandwitch with ice tea',
#  'blueberry cheesecake belgian',
#  'rosted piastachio',
#  'horlicks nutella pancake medium',
#  'bruschetta salsa n cheese swiggy',
#  'french fry nacho',
#  'twix pancake',
#  'apple cinnamon rush ww',
#  'chocolate eclair dessert',
#  'mo  hand cream fleur doranger   ml',
#  'brownie nutella puffle',
#  'fresh veggie full',
#  'veg manchurian puff',
#  'hazelnut latte',
#  'classy veg fam',
#  'acrylic removal',
#  'nutella belgian',
#  'veggies in pepper sauce',
#  'g',
#  'hot chocolate',
#  'silky chocolate shake',
#  'butter chicken',
#  'loaded hot chocolate',
#  'vanilla ice cream scoop',
#  'mango juice',
#  'blueberry cheesecake ww',
#  'mac n cheese pizza swiggy',
#  'maple  butter pancake',
#  'strawberry cooler',
#  'brownie w white chocolate ww',
#  'burrito bowl',
#  'cookie dough single',
#  'pepper chicken',
#  'meal box',
#  'veg shawarma',
#  'whisky black label jwdf',
#  '',
#  ...]

# %%
# Notice that many words are removed in the cleaning process
print(len(keywords))
# Out:
# 27715

# %%
nlp = en_core_web_md.load()

# %%
import itertools
import numpy as np
from __future__ import unicode_literals

# %% [markdown]
# I've considered these five labels to classify the data.

# %%
topic_labels = [
  'Veg',
  'Non-Veg',
  'Non-alcoholic beverages',
  'Alcoholic beverages',
  'Desserts'
]

# %% [markdown]
# *After taking a good look at our raw data, I've taken several keywords which can be associated with the labels. These will help us in getting a good accuracy score.*
#
# They can be further tweaked a bit to impove accuracy more

# %%
topic_keywords=[
    'veg vegetable paneer potato aloo dal cheese wrap',
    'chicken muttton fish prawn bacon pepperoni omellete shawrma',
    'milk tea coffee shake soup soft drinks cafe juice frappe cappuccino',
    'beer whisky alcohol vodka mojito',
    'mousse pancakes nutella waffles pastry choco chocolate brownie cake ice cream'
]

# %%
topic_docs = list(nlp.pipe(topic_keywords, batch_size=10000,
  n_threads=3))

# %%
topic_vectors = np.array([doc.vector 
  if doc.has_vector else spacy.vocab[0].vector
  for doc in topic_docs])

# %%
# Print topic vector for our first label, Veg
print(topic_labels[0])
print(topic_vectors[0])
# Out:
# Veg
# [-3.24378878e-01 -7.63103738e-02  3.97118747e-01  2.39687487e-02
#   5.06347492e-02  7.03979969e-01 -1.82393640e-02 -2.02608362e-01
#   7.28636086e-02  4.54423606e-01 -5.68820000e-01  2.47344241e-01
#  -1.84499115e-01 -1.64249688e-01  2.48333752e-01 -1.51596755e-01
#   1.57408506e-01  9.88685012e-01  2.48468995e-01  2.24234939e-01
#   8.03420097e-02  4.71788719e-02 -2.19443738e-02  2.57407516e-01
#   6.72015026e-02 -1.62577614e-01 -3.42857778e-01  3.39884222e-01
#   1.92930490e-01 -6.35887504e-01 -1.47502497e-01  9.75522473e-02
#   2.10239977e-01 -4.10250008e-01  2.41726354e-01  1.81529433e-01
#   9.83289108e-02  1.07892379e-01 -7.45120049e-02  4.51712877e-01
#   1.13021001e-01 -1.09365001e-01 -1.28557712e-01 -3.97226252e-02
#  -8.30580071e-02  4.96325999e-01 -3.26073691e-02  4.77239996e-01
#  -7.17169419e-02  3.41127515e-01  5.30605018e-02 -2.06014737e-01
#   4.22744483e-01 -1.77046254e-01  3.37481260e-01 -4.00706261e-01
#   1.29671007e-01  1.39504254e-01  1.78783610e-02  1.02693997e-01
#   4.96412516e-02 -1.18289568e-01  2.07803771e-02  3.44637521e-02
#   3.00196290e-01 -7.37428665e-01 -9.17631239e-02  1.91814512e-01
#  -6.00047521e-02  1.52164519e-01 -1.89051121e-01  6.34391248e-01


# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
simple_sim = cosine_similarity(keyword_vectors, topic_vectors)
topic_idx = simple_sim.argmax(axis=1)
print(simple_sim)
# Out:
# [[0.34263933 0.2565931  0.3108404  0.1452301  0.25741756]
#  [0.6251325  0.56232715 0.825355   0.5810569  0.80771744]
#  [0.52496713 0.46872646 0.7803726  0.614789   0.58035344]
#  ...
#  [0.4013421  0.36484957 0.51594746 0.42516547 0.4331894 ]
#  [0.6017383  0.54553306 0.7253492  0.63016653 0.5587209 ]
#  [0.42670894 0.36803028 0.6208189  0.63371706 0.46583572]]

# %%
p=[]

# %% [markdown]
# # 5. Classifying

# %%
for k, i in zip(keywords, topic_idx):
  p.append((k, topic_labels[i]))

# %%
from numpy import array
final=array(p)

# %%
final
# Out:
# array([['peri peri wrap', 'Veg'],
#        ['milk chocolate tub', 'Non-alcoholic beverages'],
#        ['soft drinks large', 'Non-alcoholic beverages'],
#        ...,
#        ['thums up  ml', 'Non-alcoholic beverages'],
#        ['fruit wine large', 'Non-alcoholic beverages'],
#        ['coca cola  ml', 'Alcoholic beverages']], dtype='<U87')

# %% [markdown]
# This is the section where we could have concatenated id back with the classified dataset

# %%
#np.concatenate([final,df1])

# %% [markdown]
# # 6. Exporting final results

# %%
df = pd.DataFrame(final, columns = ['Item Name','Item Type'])

# %%
df.to_csv('data.csv', index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27715 entries, 0 to 27714
# Data columns (total 2 columns):
# Item Name    27715 non-null object
# Item Type    27715 non-null object
# dtypes: object(2)
# memory usage: 433.1+ KB

# %% [markdown]
# ## 6.1 Viewing the results

# %%
df.head(30)
# Out:
#                             Item Name                Item Type
# 0                      peri peri wrap                      Veg
# 1                  milk chocolate tub  Non-alcoholic beverages
# 2                   soft drinks large  Non-alcoholic beverages
# 3                     cheese omellete                  Non-Veg
# 4                          cheesy dip                      Veg
# 5   blueberry cream cheese sw waffles                 Desserts
# 6                          cafe mocha  Non-alcoholic beverages
# 7               exotic veg with sauce                      Veg
# 8                        basket chaat                      Veg
# 9                    red paprika half                      Veg
# 10              oreo obsessed pancake                 Desserts
# 11                   raspberry medium  Non-alcoholic beverages
# 12             chicken nuggets swiggy                  Non-Veg
# 13               chicken garlic salad                      Veg
# 14                  nuts over nutella                 Desserts
# 15                marshmallow brownie                 Desserts
# 16                    delivery charge  Non-alcoholic beverages
# 17  schezwan paneer pizza waffle half                      Veg
# 18               espresso  cappuccino  Non-alcoholic beverages
# 19                      matka chicken                  Non-Veg
# 20                  pizza waffle full                 Desserts
# 21              cottage cheese panino                      Veg
# 22                         xtra honey  Non-alcoholic beverages
# 23      banana  salted caramel puffle                 Desserts
# 24              nasty nutella pancake                 Desserts
# 25                whisky black  white      Alcoholic beverages
# 26                           bbq wrap                      Veg
# 27                     veg fried rice                      Veg
# 28                         feta greek                      Veg
# 29                 penne creamy pesto                      Veg

# %% [markdown]
# As we can see, many of the items are correctly classified. There are still some problems, in which there contains both keywords from more than one category.

# %% [markdown]
# # 7. Conclusion

# %% [markdown]
# I used a totally different approach this time and the results are a bit satisfactory to the previous ones.
#
# There still persist some issues, and I will solve them.
#     1. No data visualiations
#     2. Getting a exact accuracy score
#     3. Item_id issue
#
# Almost all the pointers which you suggested have been taken into consideration:
#     1. Meta-labelling
#     2. Removing text data like delivery charges, etc
#     3. Deleting the item_ids(not solved)
#
# Due to your helpful pointers, we got a better accuracy in this attempt.

# %% [markdown]
# **Thank you for reading**
